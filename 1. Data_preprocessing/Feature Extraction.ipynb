# %% [markdown]
# #  Feature selection

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_val_score
from sklearn .linear_model import LogisticRegression

import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\suraj\Desktop\MLearning\python\1. Data_preprocessing\titanic.csv', usecols = ['Age','Pclass','SibSp','Parch','Survived'])

# %%
df.sample(5)
# Out:
#      Survived  Pclass   Age  SibSp  Parch
# 12          1       1  23.0      1      0
# 386         0       3  24.0      0      0
# 41          0       1   NaN      0      0
# 277         0       2  40.0      1      0
# 46          0       1  45.0      0      0

# %%
df.shape
# Out:
# (418, 5)

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch
# 0         0       3  34.5      0      0
# 1         1       3  47.0      1      0
# 2         0       2  62.0      0      0
# 3         0       3  27.0      0      0
# 4         1       3  22.0      1      1

# %%
X = df.iloc[:,1:]
y  = df.iloc[:,1]

# %%
X
# Out:
#      Pclass   Age  SibSp  Parch
# 0         3  34.5      0      0
# 1         3  47.0      1      0
# 2         2  62.0      0      0
# 3         3  27.0      0      0
# 4         3  22.0      1      1
# ..      ...   ...    ...    ...
# 409       3   3.0      1      1
# 411       1  37.0      1      0
# 412       3  28.0      0      0
# 414       1  39.0      0      0
# 415       3  38.5      0      0
#
# [332 rows x 4 columns]

# %%
# finding cross validation score
np.mean(cross_val_score(LogisticRegression(),X,y,scoring = 'accuracy',cv = 30))
# Out:
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ### Applying Feature Construction

# %%
X[ 'Family_size'] = X['SibSp']+X['Parch']+1

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch  Family_size
# 0       3  34.5      0      0            1
# 1       3  47.0      1      0            2
# 2       2  62.0      0      0            1
# 3       3  27.0      0      0            1
# 4       3  22.0      1      1            3

# %%
def myfunc(x):
    if x == 1:
        return 0
    elif x>1 and x<=4:
        return 1 # small family
    else:
        return 2 # large family

# %%
X['Family_type'] = X['Family_size'].apply(myfunc)

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch  Family_size  Family_type
# 0       3  34.5      0      0            1            0
# 1       3  47.0      1      0            2            1
# 2       2  62.0      0      0            1            0
# 3       3  27.0      0      0            1            0
# 4       3  22.0      1      1            3            1

# %%
X.drop(['SibSp','Parch',"Family_size"]  ,axis =1)
# Out:
#      Pclass   Age  Family_type
# 0         3  34.5            0
# 1         3  47.0            1
# 2         2  62.0            0
# 3         3  27.0            0
# 4         3  22.0            1
# ..      ...   ...          ...
# 409       3   3.0            1
# 411       1  37.0            1
# 412       3  28.0            0
# 414       1  39.0            0
# 415       3  38.5            0
#
# [332 rows x 3 columns]

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=20))
# Out:
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #####  Errror
# lbfgs stand for: “Limited-memory Broyden–Fletcher–Goldfarb–Shanno Algorithm”. It is one of the solvers’ algorithms provided by Scikit-Learn Library.
#
# The term limited-memory simply means it stores only a few vectors that represent the gradients approximation implicitly.
#
# It has better convergence on relatively small datasets.
#
# what is algorithm convergence?
#
# In simple words. If the error of solving is ranging within very small range (i.e., it is almost not changing), then that means the algorithm reached the solution (not necessary to be the best solution as it might be stuck at what so-called “local Optima”).
#
# On the other hand, if the error is varying noticeably (even if the error is relatively small [like in your case the score was good], but rather the differences between the errors per iteration is greater than some tolerance) then we say the algorithm did not converg

# %% [markdown]
# ### Feature splitting

# %%
data= pd.read_csv(r'C:\Users\suraj\Desktop\MLearning\python\1. Data_preprocessing\titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data['Title']=data['Name'].str.split(',',expand =True)[1].str.split('.',expand = True)[0]

# %%
# shows example
data['Name'].str.split(',',expand =True)[1].str.split('.')[0]
# Out:
# [' Mr', ' James']

# %% [markdown]
# expand : bool, default False
#
# Expand the splitted strings into separate columns.
#
# If True, return DataFrame/MultiIndex expanding dimensionality.
# If False, return Series/Index, containing lists of strings.

# %%
data[['Title','Name']]
# Out:
#        Title                                          Name
# 0         Mr                              Kelly, Mr. James
# 1        Mrs              Wilkes, Mrs. James (Ellen Needs)
# 2         Mr                     Myles, Mr. Thomas Francis
# 3         Mr                              Wirz, Mr. Albert
# 4        Mrs  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..       ...                                           ...
# 413       Mr                            Spector, Mr. Woolf
# 414     Dona                  Oliva y Ocana, Dona. Fermina
# 415       Mr                  Saether, Mr. Simon Sivertsen
# 416       Mr                           Ware, Mr. Frederick
# 417   Master                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
(data.groupby('Title').mean(numeric_only =True)['Survived']).sort_values(ascending = False)
# Out:
# Title
#  Dona      1.0
#  Miss      1.0
#  Mrs       1.0
#  Ms        1.0
#  Col       0.0
#  Dr        0.0
#  Master    0.0
#  Mr        0.0
#  Rev       0.0
# Name: Survived, dtype: float64

# %%
# now you can also make a column of maried people
data['Is_married'] = 0
data['Is_married'].loc[data['Title']=='Mrs'] = 1
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_17320\3230222157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Is_married'].loc[data['Title']=='Mrs'] = 1

# %%
data['Is_married']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    0
# Name: Is_married, Length: 418, dtype: int64
